# %% [markdown]
# # Scientific Paper Style Data Description
#
# Use this notebook to draft a reproducible, publication-ready description of a dataset, including provenance, structure, and quality controls.

# %% [markdown]
# ## 1. Dataset Overview
# - **Name/Identifier:**
# - **Purpose:**
# - **Primary Source(s):**
# - **Collection Dates:**
# - **Geographic/Population Scope:**
# - **Licensing/Usage Constraints:**

# %% [markdown]
# ## 2. Data Acquisition and Preprocessing
# - **Acquisition Protocol:**
# - **Inclusion/Exclusion Criteria:**
# - **Preprocessing Steps:**
# - **Normalization/Standardization:**
# - **Handling Missing Values:**
# - **Data Splits (train/val/test):**

# %% [markdown]
# ## 3. Data Schema and Formats
# Describe the structure of the dataset (files, tables, fields, and metadata).
#
# - **Files/Artifacts:**
# - **Record Count:**
# - **Feature Types:**
# - **Target Labels (if any):**
# - **Units and Scales:**
# - **Versioning:**

# %% [markdown]
# ## 4. Quality Control and Validation
# - **Data Validation Checks:**
# - **Outlier Detection/Handling:**
# - **Noise Reduction Steps:**
# - **Inter-annotator Agreement (if applicable):**
# - **Known Limitations/Biases:**

# %% [markdown]
# ## 5. Descriptive Statistics (Optional)
# Summarize key statistics or include plots/tables to describe distributions.
#
# - **Summary Metrics:**
# - **Class Balance:**
# - **Feature Distributions:**
# - **Correlation Notes:**

# %% [markdown]
# ## 6. Ethical Considerations
# - **Consent/Privacy:**
# - **Sensitive Attributes:**
# - **Potential Misuse Risks:**
# - **Mitigation Steps:**

# %% [markdown]
# ## 7. Reproducibility and Access
# - **Access Instructions:**
# - **Checksums/Hashes:**
# - **Dependencies for Loading:**
# - **Contact/Support:**
